# %%
import pandas as pd

# %%
Data = pd.read_csv('COVID-19 Dataset.csv')

# %%
Data.head(10)
# Out:
#        Date State Cases_Total Cases_White  Cases_Black  Cases_LatinX  \
# 0  20201018    AK       12016        4072        493.0           NaN
# 1  20201018    AL      172626       53458      36048.0           NaN
# 2  20201018    AR       99066       58151      20110.0           NaN
# 3  20201018    AS         NaN         NaN          NaN           NaN
# 4  20201018    AZ      231149       60107       7158.0       71227.0
# 5  20201018    CA      867317      106404      25928.0      373742.0
# 6  20201018    CO       85302       32414       3241.0       31374.0
# 7  20201018    CT       62830       21505       7767.0       12235.0
# 8  20201018    DC       16370        3670       8179.0           NaN
# 9  20201018    DE       23093        8910       6045.0        5059.0
#
#    Cases_Asian  Cases_AIAN  Cases_NHPI  Cases_Multiracial  ...  Deaths_LatinX  \
# 0        548.0      2519.0       526.0              522.0  ...            NaN
# ...
